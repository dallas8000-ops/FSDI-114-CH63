# %%
# Helper functions for stack operations
def push(stack, item):
    stack.append(item)
stack.append("B")
push(stack, "C")

# 3. Pop the top value and store it in a variable called top.
top = pop(stack)

# 4. Print the entire stack and print the value that was removed.
print("Stack after popping top:", stack)
print("Value removed (top):", top)

# 5. Pop the next value from the stack and print it.
next_value = pop(stack)
print("Next value removed:", next_value)

# 6. Push the value "D" onto the stack.
push(stack, "D")

# 7. Pop again and print the removed value.
removed = pop(stack)
print("Removed value after pushing D:", removed)

# 8. Print the entire stack.
print("Final stack:", stack)
            "metadata": {
                "language": "markdown"
            },
            "source": [
                "1"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-4ca7b112",
            "metadata": {
                "language": "python"
            },
            "source": [
                "# 1. Create an empty stack.",
                "stack = []",
                "",
                "# 2. Push the values \"A\", \"B\", and \"C\" onto the stack in that order.",
                "stack.append(\"A\")",
                "stack.append(\"B\")",
                "push(stack, \"C\")",
                "",
                "# 3. Pop the top value and store it in a variable called top.",
                "top = pop(stack)",
                "",
                "# 4. Print the entire stack and print the value that was removed.",
                "print(\"Stack after popping top:\", stack)",
                "print(\"Value removed (top):\", top)",
                "",
                "# 5. Pop the next value from the stack and print it.",
                "next_value = pop(stack)",
                "print(\"Next value removed:\", next_value)",
                "",
                "# 6. Push the value \"D\" onto the stack.",
                "push(stack, \"D\")",
                "",
                "# 7. Pop again and print the removed value.",
                "removed = pop(stack)",
                "print(\"Removed value after pushing D:\", removed)",
                "",
                "# 8. Print the entire stack.",
                "print(\"Final stack:\", stack)",
                "",
                ""
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-47e103cd",
            "metadata": {
                "language": "python"
            },
            "source": [
                "# Challenge 2: Last item on the stack",
                "# 1. Push 4 numbers.",
                "# 2. Print only the top without removing it. ",
                "",
                "def peek(stack):",
                "    if len(stack) > 0:",
                "        return stack[-1]",
                "    else:",
                "        return None",
                "",
                "stack = []",
                "stack.append(10)",
                "stack.append(20)",
                "stack.append(30)",
                "stack.append(40)",
                "",
                "print(\"Stack:\", stack)",
                "print(\"Top item (peek):\", peek(stack))"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-fc5b4137",
            "metadata": {
                "language": "python"
            },
            "source": [
                "# Challenge 3: Is the stack empty?",
                "# 1. Make an empty stack.",
                "# 2. Check if it's empty.",
                "# 3. Print a message.",
                "",
                "def is_empty(stack):",
                "    return len(stack) == 0",
                "",
                "stack = []",
                "",
                "if is_empty(stack):",
                "    print(\"The stack is empty.\")",
                "else:",
                "    print(\"The stack is not empty.\")"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-8c26fe07",
            "metadata": {
                "language": "python"
            },
            "source": [
                "# Challenge 4: Reverse a word",
                "# 1. Reverse the word \"Hello\" using a stack",
                "",
                "word = \"Hello\"",
                "stack = []",
                "",
                "# Push each character ",
                "for char in word:",
                "    stack.append(char)",
                "",
                "# Pop characters to reverse the word",
                "reversed_word = \"\"",
                "while len(stack) > 0:",
                "    reversed_word += stack.pop()",
                "",
                "print(\"Original word:\", word)",
                "print(\"Reversed word:\", reversed_word)"
            ]
        }
    ]
# Out:
#   File <string>:44
#     },
#       ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## Challenge 5: Enqueue three items
# **Instructions:**
# 1. Create a queue with the values **2**, **4**, **6**.
# 2. Enqueue the values **8**, **10**, and **12**.
# 3. Print the final queue.

# %%
# Challenge 5: Enqueue three items
queue = []  # Create an empty queue
queue.append(10)  # Enqueue 10
queue.append(20)  # Enqueue 20
queue.append(30)  # Enqueue 30
print("Queue after enqueuing 10, 20, 30:", queue)
# Out:
# Queue after enqueuing 10, 20, 30: [10, 20, 30]

# %% [markdown]
# ## Challenge 6: Dequeue one item
# **Instructions:**
# 1. Create a queue with the values **5**, **6**, **7**, **8**.
# 2. Dequeue one item.
# 3. Print the value removed and the final queue.

# %%
# Challenge 6: Dequeue one item
queue = [5, 6, 7, 8]  # Create a queue with the values 5, 6, 7, 8
removed = queue.pop(0)  # Dequeue one item (FIFO)
print("Value removed:", removed)
print("Final queue:", queue)
# Out:
# Value removed: 5
# Final queue: [6, 7, 8]

# %% [markdown]
# ## Challenge 7: Check if the queue is empty
# **Instructions:**
# 1. Create an empty queue.
# 2. Check if it’s empty.
# 3. Print a message depending on the result.

# %%
# Challenge 7: Check if the queue is empty
queue = []  # Create an empty queue
if len(queue) == 0:
    print("The queue is empty.")
else:
    print("The queue is not empty.")
# Out:
# The queue is empty.

# %% [markdown]
# # Class 2 – Stacks and Queues
#
# ## Stacks
# A stack is an ordered collection of elements where items are added and removed from only one end, called the top of the stack. This is known as Last-In, First-Out (LIFO) principle.
#
# ## Queues
# A queue is an ordered collection of elements where items are added at one end (the rear) and removed from the other end (the front). This is known as First-In, First-Out (FIFO) principle.

# %% [markdown]
# 1

# %%
# Helper functions for stack operations
def push(stack, item):
    stack.append(item)

def pop(stack):
    if len(stack) > 0:
        return stack.pop()
    else:
        return None

# 1. Create an empty stack.
stack = []

# 2. Push the values "A", "B", and "C" onto the stack in that order.
stack.append("A")
stack.append("B")
push(stack, "C")

# 3. Pop the top value and store it in a variable called top.
top = pop(stack)

# 4. Print the entire stack and print the value that was removed.
print("Stack after popping top:", stack)
print("Value removed (top):", top)

# 5. Pop the next value from the stack and print it.
next_value = pop(stack)
print("Next value removed:", next_value)

# 6. Push the value "D" onto the stack.
push(stack, "D")

# 7. Pop again and print the removed value.
removed = pop(stack)
print("Removed value after pushing D:", removed)

# 8. Print the entire stack.
print("Final stack:", stack)
# Out:
# Stack after popping top: ['A', 'B']
# Value removed (top): C
# Next value removed: B
# Removed value after pushing D: D
# Final stack: ['A']

# %%
# Challenge 2: Last item on the stack
# 1. Push 4 numbers.
# 2. Print only the top without removing it. 

def peek(stack):
    if len(stack) > 0:
        return stack[-1]
    else:
        return None

stack = []
stack.append(10)
stack.append(20)
stack.append(30)
stack.append(40)

print("Stack:", stack)
print("Top item (peek):", peek(stack))
# Out:
# Stack: [10, 20, 30, 40]
# Top item (peek): 40

# %%
# Challenge 3: Is the stack empty?
# 1. Make an empty stack.
# 2. Check if it's empty.
# 3. Print a message.

def is_empty(stack):
    return len(stack) == 0

stack = []

if is_empty(stack):
    print("The stack is empty.")
else:
    print("The stack is not empty.")
# Out:
# The stack is empty.

# %%
# Challenge 4: Reverse a word
# 1. Reverse the word "Hello" using a stack

word = "Hello"
stack = []

# Push each character 
for char in word:
    stack.append(char)

# Pop characters to reverse the word
reversed_word = ""
while len(stack) > 0:
    reversed_word += stack.pop()

print("Original word:", word)
print("Reversed word:", reversed_word)
# Out:
# Original word: Hello
# Reversed word: olleH

# %%
class Stack:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            return None

    def size(self):
        return len(self.items)

# Example usage:
stack = Stack()
stack.push(10)
stack.push(20)
print('Top item:', stack.peek())
print('Stack size:', stack.size())
print('Popped:', stack.pop())
print('Is empty?', stack.is_empty())
# Out:
# Top item: 20
# Stack size: 2
# Popped: 20
# Is empty? False
