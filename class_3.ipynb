# %% [markdown]
# ## Mini Challenge #2: Stack Class Implementation
#
# This notebook demonstrates a `Stack` class with the following methods:
# - `is_empty()` returns True if the stack is empty
# - `push(item)` adds an item to the stack
# - `pop()` removes and returns the top item
# - `peek()` returns the top item without removing it
# - `size()` returns the number of items in the stack

# %%
class Stack:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            return None

    def size(self):
        return len(self.items)

# Example usage:
stack = Stack()
stack.push(10)
stack.push(20)
print('Top item:', stack.peek())
print('Stack size:', stack.size())
print('Popped:', stack.pop())
print('Is empty?', stack.is_empty())
# Out:
# Top item: 20
# Stack size: 2
# Popped: 20
# Is empty? False

# %%
# Create a stack
stack1 = Stack()

# Push three items
stack1.push(5)
stack1.push(10)
stack1.push(15)

# Peek at the top item
print("Stack peek:", stack1.peek())

# Pop the top item
print("Stack pop:", stack1.pop())

# Check the size
print("Stack size:", stack1.size())
# Out:
# Stack peek: 15
# Stack pop: 15
# Stack size: 2

# %% [markdown]
# ## Mini Challenge #3: push() Method
#
# Implement the `push()` method for the Stack class so that it adds an item to the top of the stack.
#
# **Instructions:**
# - Define the `push(self, item)` method inside the Stack class.
# - The method should append the given item to the `items` list.
# - Test your method by pushing a few values and printing the stack.

# %%
# Mini Challenge #3: push() Method

# Assume the Stack class is already defined above
stack = Stack()
stack.push('item1')
stack.push('item2')
stack.push('item3')
print('Stack items:', stack.items)

# %% [markdown]
# ## Mini Challenge #3: push() Method
#
# Implement the `push()` method for the Stack class so that it adds an item to the top of the stack.
#
# **Instructions:**
# - Define the `push(self, item)` method inside the Stack class.
# - The method should append the given item to the `items` list.
# - Test your method by pushing a few values and printing the stack.

# %%
# Mini Challenge #3: push() Method

# Assume the Stack class is already defined above
stack = Stack()
stack.push('item1')
stack.push('item2')
stack.push('item3')
print('Stack items:', stack.items)
# Out:
# Stack items: ['apple', 'banana', 'cherry']

# %% [markdown]
# ## Mini Challenge #4: pop() Method
#
# Write the `pop()` method for the Stack class. It should return the last item and remove it. If the stack is empty, return `None`.
#
# **Instructions:**
# - Define the `pop(self)` method inside the Stack class.
# - The method should remove and return the last item in the `items` list.
# - If the stack is empty, return `None`.
# - Test your method by popping values from the stack and printing the result.

# %%
# Mini Challenge #4: pop() Method

# Assume the Stack class is already defined above
stack = Stack()
stack.push('item1')
stack.push('item2')
stack.push('item3')
print('Popped:', stack.pop())  # Should print 'item3'
print('Stack after pop:', stack.items)
print('Popped:', stack.pop())  # Should print 'item2'
print('Stack after pop:', stack.items)
print('Popped:', stack.pop())  # Should print 'item1'
print('Stack after pop:', stack.items)
print('Popped from empty stack:', stack.pop())  # Should print None
# Out:
# Popped: item3
# Stack after pop: ['item1', 'item2']
# Popped: item2
# Stack after pop: ['item1']
# Popped: item1
# Stack after pop: []
# Popped from empty stack: None

# %% [markdown]
# ## Mini Challenge #5: peek() and size() Methods
#
# Now add two more methods to your Stack class:
# - `peek()` → return the top item
# - `size()` → return the number of items
#
# **Instructions:**
# - Define the `peek(self)` method to return the top item of the stack (or `None` if empty).
# - Define the `size(self)` method to return the number of items in the stack.
# - Test your methods by calling them and printing the results.

# %%
# Mini Challenge #5: peek() and size() Methods

# Define a Stack class with peek() and size() methods
class Stack:
    def __init__(self):
        self.items = []
    def peek(self):
        if self.items:
            return self.items[-1]
        else:
            return None
    def size(self):
        return len(self.items)
    def push(self, item):
        self.items.append(item)
    def pop(self):
        if self.items:
            return self.items.pop()
        else:
            return None

# Test the new methods
stack = Stack()
stack.push('item1')
stack.push('item2')
stack.push('item3')
print('Top item (peek):', stack.peek())  # Should print 'item3'
print('Stack size:', stack.size())       # Should print 3
stack.pop()
print('Top item (peek) after pop:', stack.peek())  # Should print 'item2'
print('Stack size after pop:', stack.size())       # Should print 2
# Out:
# Top item (peek): item3
# Stack size: 3
# Top item (peek) after pop: item2
# Stack size after pop: 2

# %%
# Create a stack
stack1 = Stack()

# Push three items
stack1.push(5)
stack1.push(10)
stack1.push(15)

# Peek at the top item
print("Stack peek:", stack1.peek())

# Pop the top item
print("Stack pop:", stack1.pop())

# Check the size
print("Stack size:", stack1.size())
# Out:
# Stack peek: 15
# Stack pop: 15
# Stack size: 2

# %% [markdown]
# ## Mini Challenge #6: Queue Class Implementation
#
# Create a `Queue` class with the following methods:
# - `is_empty()` returns True if the queue is empty
# - `enqueue(item)` adds an item to the end of the queue
# - `dequeue()` removes and returns the front item
# - `peek()` returns the front item without removing it
# - `size()` returns the number of items in the queue

# %%
# Mini Challenge #6: Queue Class Implementation
"""
Implement a Queue class with the following methods:
- is_empty() returns True if the queue is empty
- enqueue(item) adds an item to the end of the queue
- dequeue() removes and returns the front item
- peek() returns the front item without removing it
- size() returns the number of items in the queue
"""

class Queue:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def enqueue(self, item):
        self.items.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.items.pop(0)
        else:
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[0]
        else:
            return None

    def size(self):
        return len(self.items)

# %% [markdown]
# ## Mini Challenge #7: is_empty() Method
#
# Implement and test the `is_empty()` method for the Queue class.
#
# **Instructions:**
# - The `is_empty(self)` method should return `True` if the queue is empty, otherwise `False`.
# - Test your method by creating a new queue, checking if it is empty, adding an item, and checking again.

# %%
# Mini Challenge #7: is_empty() Method
queue = Queue()
print('Is the queue empty?', queue.is_empty())  # Should print True
queue.enqueue(42)
print('Is the queue empty after enqueue?', queue.is_empty())  # Should print False
# Out:
# Is the queue empty? True
# Is the queue empty after enqueue? False

# %% [markdown]
# ## Mini Challenge #8: enqueue() Method
#
# Write the `enqueue()` method for the Queue class to add an item to the back of the queue using `append()`.
#
# **Instructions:**
# - Define the `enqueue(self, item)` method inside the Queue class.
# - The method should use `self.items.append(item)` to add the item to the end of the queue.
# - Test your method by enqueuing a few values and printing the queue.

# %%
# Mini Challenge #8: enqueue() Method
queue = Queue()
queue.enqueue(1)
queue.enqueue(2)
queue.enqueue(3)
print('Queue items:', queue.items)  # Should print [1, 2, 3]
# Out:
# Queue items: [1, 2, 3]

# %% [markdown]
# ### Mini Challenge #9: dequeue() Method
#
# Implement `dequeue()`.
# - It should remove and return the item at the front of the queue, which is index 0.
# - If the queue is empty, return `None`.

# %%
# Mini Challenge #9: dequeue() Method
queue9 = Queue()
queue9.enqueue(10)
queue9.enqueue(20)
queue9.enqueue(30)
print('Queue before dequeue:', queue9.items)  # Should print [10, 20, 30]
print('Dequeued item:', queue9.dequeue())      # Should print 10
print('Queue after dequeue:', queue9.items)    # Should print [20, 30]
print('Dequeued from empty queue:', Queue().dequeue())  # Should print None
# Out:
# Queue before dequeue: [10, 20, 30]
# Dequeued item: 10
# Queue after dequeue: [20, 30]
# Dequeued from empty queue: None

# %% [markdown]
# ## Challenge #10: size() Method
#
# Implement a `size()` method for a class so that it returns the number of items in the collection.
#
# **Instructions:**
# - Define a class with an `items` list.
# - Implement a `size(self)` method that returns the number of items.
# - Test your method by adding items and printing the result.

# %%
# Challenge #10: size() Method implementation and test

class Challenge10:
    def __init__(self):
        self.items = []
    def size(self):
        return len(self.items)

# Test the size() method
obj = Challenge10()
obj.items.extend([1, 2, 3, 4])
print('Number of items:', obj.size())  # Should print 4

# %%
# Test all Queue methods
queue = Queue()
print('Initially empty:', queue.is_empty())  # True
queue.enqueue('a')
queue.enqueue('b')
queue.enqueue('c')
print('After enqueue:', queue.items)         # ['a', 'b', 'c']
print('Peek:', queue.peek())                # 'a'
print('Size:', queue.size())                # 3
print('Dequeued:', queue.dequeue())         # 'a'
print('After dequeue:', queue.items)        # ['b', 'c']
print('Dequeued:', queue.dequeue())         # 'b'
print('Dequeued:', queue.dequeue())         # 'c'
print('Dequeued from empty:', queue.dequeue())  # None
print('Is empty after all dequeues:', queue.is_empty())  # True
print('Peek on empty:', queue.peek())       # None
print('Size on empty:', queue.size())       # 0
# Out:
# Initially empty: True
# After enqueue: ['a', 'b', 'c']
# Peek: a
# Size: 3
# Dequeued: a
# After dequeue: ['b', 'c']
# Dequeued: b
# Dequeued: c
# Dequeued from empty: None
# Is empty after all dequeues: True
# Peek on empty: None
# Size on empty: 0
